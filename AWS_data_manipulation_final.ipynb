# %%
import pymysql
host = "database-job-posts.c1qytdm4eno0.us-east-1.rds.amazonaws.com"

port =int(3306)
dbname="job_posts"
user="timaun4db"
password="WSsmdIep4db2e"
conn = pymysql.connect(host, user=user,port=port, passwd=password, db=dbname,charset='latin1')

# %%
import pandas as pd
data1 =pd.read_sql('SELECT * from temp_data', con=conn)
data1.shape
# Out:
# (322057, 10)

# %%
#### remove wrong data collection
data_correct = data1[data1['date'] !='''If you require alternative methods of application or screening, you must approach the employer directly to request this as Indeed is not responsible for the employer's application process.''']
data_correct.shape
# Out:
# (319719, 10)

# %%
data_correct.drop(['date','day'], axis =1, inplace = True)
# Out:
# C:\Users\mh4pk\AppData\Local\Continuum\anaconda3\envs\scrapyenv2\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_correct.shape
# Out:
# (319719, 8)

# %%
# dropping duplicates due to overlap of periods
no_overlap_data=data_correct[~data_correct.duplicated()]
no_overlap_data.shape
# Out:
# (261110, 8)

# %%
# copy a backup of data to hard drive
no_overlap_data.to_csv('April-10-backup.csv', index = False)

# %%
import pandas as pd
retrived_data = pd.read_csv('C:/Users/mh4pk/Downloads/April-10-backup.csv')

# %%
droped_dup_data = retrived_data[~retrived_data[['job_title', 'company', 'description',
       'state', 'city','posted_date']].duplicated()]
droped_dup_data.shape
# Out:
# (244681, 8)

# %%
from collections import Counter
Counter(droped_dup_data.term)
# Out:
# Counter({'data analyst': 129321,
#          'machine learning engineer': 71997,
#          'data scientist': 43363})

# %%
Counter(droped_dup_data.state)
# Out:
# Counter({'DC': 8124,
#          'AL': 1631,
#          'AR': 972,
#          'AZ': 4152,
#          'CO': 5182,
#          'CA': 32384,
#          'CT': 2628,
#          'DE': 1529,
#          'FL': 8169,
#          'GA': 6842,
#          'HI': 579,
#          'IA': 1566,
#          'ID': 809,
#          'IL': 10049,
#          'Illinois': 257,
#          'Iowa': 45,
#          'Hawaii': 35,
#          'Florida': 170,
#          'California': 955,
#          'Colorado': 220,
#          'Arizona': 123,
#          'IN': 2164,
#          'Indiana': 96,
#          'KY': 1179,
#          'ME': 436,
#          'KS': 1045,
#          'MO': 3465,
#          'LA': 839,
#          'MS': 392,
#          'MA': 9632,
#          'MD': 7578,
#          'MT': 272,
#          'MI': 4142,
#          'MN': 4455,
#          'Minnesota': 100,
#          'Michigan': 178,
#          'Maryland': 150,
#          'Massachusetts': 284,
#          'NC': 7430,
#          'United States': 439,
#          'NM': 886,
#          'NJ': 6672,
#          'NH': 550,
#          'New Jersey': 200,
#          'NE': 871,
#          'ND': 196,
#          'North Carolina': 185,
#          'NV': 756,
#          'NY': 14297,
#          'OH': 5443,
#          'OK': 835,
#          'PA': 7951,
#          'RI': 600,
#          'SC': 1522,
#          'TN': 3037,
#          'SD': 195,
#          'South Dakota': 8,
#          'South Carolina': 56,
#          'PR': 367,
#          'OR': 2279,
#          'Oklahoma': 43,
#          'Nevada': 41,
#          'TX': 15714,
#          'VT': 205,
#          'UT': 2128,
#          'VA': 14711,
#          'WV': 273,
#          'WA': 13779,
#          'WI': 2380,
#          'Wisconsin': 37,
#          'Texas': 527,
#          'Virginia': 286,
#          'Utah': 55,
#          'Washington State': 230,
#          'Arkansas': 32,
#          'Mississippi': 17,
#          'New Mexico': 18,
#          'New York State': 526,
#          'AK': 259,
#          'Georgia': 218,
#          'Alabama': 37,
#          'Kentucky': 26,
#          'Kansas': 30,
#          'VI': 26,
#          'Pennsylvania': 152,
#          'WY': 125,
#          'Alaska': 20,
#          'Nebraska': 34,
#          'Idaho': 24,
#          'Guam': 19,
#          'Connecticut': 54,
#          'Oregon': 135,
#          'Ohio': 105,
#          'Montana': 19,
#          'Tennessee': 62,
#          'GU': 14,
#          'North Dakota': 17,
#          'Missouri': 67,
#          'United States Minor Outlying Islands': 6,
#          'Delaware': 51,
#          'Louisiana': 26,
#          'MP': 3,
#          'Rhode Island': 25,
#          'New Hampshire': 16,
#          'Maine': 8,
#          'Virgin Islands': 1,
#          'Puerto Rico': 14,
#          'Antwerp (city)': 1,
#          'Wyoming': 18,
#          'Stuttgart': 1,
#          'West Virginia': 23,
#          'Remote': 5,
#          'Switzerland': 1,
#          'Vermont': 14,
#          'Grid Dynamics': 11,
#          'In': 1241,
#          'Virtue Group LLC': 2,
#          'Gurstel Law Firm P C': 3,
#          'Mitnick Security Consulting': 2,
#          'Ursi Technologies Inc': 9,
#          'Okaya Corp': 34,
#          'Topaz Labs': 5,
#          'Centrifuge LLC': 2,
#          'Gainwell Technologies': 108,
#          'IC-CAP': 3,
#          'Darkhorse Geospatial LLC': 1,
#          'Probity Inc.': 2,
#          'Pentrogon security': 9,
#          'Cognowiz solutions LLC': 4,
#          'Tiger Analytics': 13,
#          'Prescient Edge Federal': 18,
#          'Signal Systems Corporation': 3,
#          'Veracity Consulting Group': 1,
#          'CEDENT': 11,
#          'Luzon Technologies': 4,
#          'SphereOI Studios': 29,
#          'IVYSYS TECHNOLOGIES LLC': 4,
#          'Avantus Federal': 15,
#          'Artlin Consulting': 1,
#          'Codazen': 6,
#          'Hypergiant': 12,
#          'PLNAR': 2,
#          'Line of Business:': 2,
#          'Ad hoc Research': 7,
#          'Moveworks.ai': 8,
#          'Kinetix Trading Solutions Inc': 5,
#          'Spectral MD': 4,
#          'Oriontek Inc': 3,
#          'Harris Health System': 1,
#          'Hia Technologies': 2,
#          'Twenty20 Solutions': 1,
#          'Game Circus': 2,
#          'LL': 474,
#          'Ve': 2,
#          'Amplify Consulting Partners': 4,
#          'Seagen': 9,
#          'Amperity': 2,
#          'Moneza Inc': 2,
#          'Foxconn Industrial Internet - FII': 2,
#          'Pacific States Marine Fisheries Commission': 1,
#          'SageBeans RPO': 11,
#          'Discovery': 3,
#          'Textio': 42,
#          'Innovative Edge Consulting': 1,
#          'Qualtrics': 1,
#          'Princeton Consumer Research Corp': 1,
#          'Vyne Group': 1,
#          'Cooperative Studies Program Coordinating Center': 1,
#          'Blueprint Stats': 1,
#          'Tegus': 2,
#          'BioSource Recruiters': 3,
#          'EBI Management Group': 1,
#          'Talent Hire consulting': 3,
#          'Talent Hire Consulting': 4,
#          'STORD': 2,
#          'Atrium Staff LLC': 1,
#          'Peacebuilding solutions': 1,
#          'Suncloud LLC': 2,
#          'Clear Spring Health': 2,
#          'Cole Engineering Services Inc.': 2,
#          'PT Genie': 2,
#          'Fresko': 2,
#          'Andor Health': 8,
#          'LSQ': 2,
#          'Forcura': 7,
#          'John Snow Labs': 2,
#          'Chiefly': 1,
#          'TechSur Solutions': 8,
#          'Maestro Technologies Inc': 1,
#          'AVANGRID': 3,
#          'Innovyze': 1,
#          'Punchh': 4,
#          'FarmWise': 1,
#          'Pointillist': 1,
#          'Wells Fargo': 8,
#          'TruU': 6,
#          'Well Data Labs': 3,
#          'AcreTrader': 1,
#          '1st Edge': 2,
#          'Earnin': 2,
#          'Verkada': 2,
#          'Apton Biosystems': 2,
#          'OPPO US Research Center': 2,
#          'IceCream Labs': 4,
#          '11Health and Technologies Inc': 3,
#          'Niantic': 4,
#          'seagatetec': 2,
#          'Lexis Nexis / Reed Elsevier Technology': 2,
#          'Agari': 2,
#          'Sofar Ocean': 1,
#          'Next Insurance': 2,
#          'Corporate Dynamix': 2,
#          'Lucence Health Inc': 1,
#          'SupportLogic': 2,
#          'Influx Partners': 1,
#          'Anchor Loans LP': 8,
#          'Sensor Tower': 2,
#          'Tara AI': 1,
#          'Commonwealth Informatics Inc.': 1,
#          'BluePath Labs': 2,
#          'Kitcheck': 2,
#          'Expression Networks': 5,
#          'TAA Solutions LLC': 9,
#          'FAAZ Consulting': 9,
#          'US Other Agencies and Independent Organizations': 7,
#          'Xometry Inc': 4,
#          'CSZ Net Inc': 2,
#          'Peregrine Advisors': 1,
#          'Medical Home Network (MHN)': 1,
#          'SimBioSys': 12,
#          'Sky RPO': 3,
#          'Augmedix Inc.': 1,
#          'Nidish LLC': 1,
#          'Promethium': 2,
#          'VA Boston Healthcare System': 3,
#          'Soar Technology': 32,
#          'Panalgo': 4,
#          'Vertex Pharmaceuticals Inc (US)': 3,
#          'Gravyty': 4,
#          'Onduo': 2,
#          'Kagr Llc': 2,
#          'Day Zero Diagnostics': 2,
#          'Bridge Informatics': 1,
#          'Monte Rosa Therapeutics': 2,
#          'Generation Bio': 2,
#          'PRECISIONheor': 2,
#          'in': 8,
#          'Decisions Oriented Inc.': 1,
#          'Capital One': 3,
#          'Kessel Run': 2,
#          'Plume': 6,
#          'Abnormal Security': 2,
#          'TuSimple Internship Program': 3,
#          'Triplebyte Partner Companies': 2,
#          'Lark Health': 7,
#          'Verve Group': 4,
#          'DeepVu': 3,
#          'Penumbra US': 3,
#          'Brex': 11,
#          'Berkeley Coding Academy': 4,
#          'STAR Labs': 4,
#          'Yummly': 4,
#          'Aisera': 3,
#          'PubNative GmbH': 1,
#          'Zest AI': 6,
#          'Relyance Inc.': 2,
#          'OffWorld': 1,
#          'LiveEO': 1,
#          'Reflex Media Inc.': 1,
#          'FlexIT Inc': 21,
#          'Eduworks Corporation': 2,
#          'Cascade Data Labs': 1,
#          'N.': 65,
#          'Daily Harvest': 1,
#          'Hyumn Inc.': 1,
#          'EvTek': 3,
#          'OK Cupid': 2,
#          'Aquant': 1,
#          'PebblePost': 1,
#          'Reflex Media Inc': 1,
#          'SPECTRUM': 4,
#          'Amador Bioscience Inc': 2,
#          'A Telecom Service Provider': 1,
#          'Rigas tech inc': 1,
#          'Dataplus Pharma Services': 1,
#          'Adstra': 1,
#          'AGM Tech Solutions': 2,
#          'Hash Technologies': 9,
#          'Martian Wall Pvt Ltd': 7,
#          'Thirty Madison': 4,
#          'Whiterock AI': 1,
#          'Compass': 20,
#          'PRISM Spectrum Holdings': 1,
#          'Balto': 2,
#          'VMLY&R': 1,
#          'eTek IT Service | Savvysol': 7,
#          'Starkey Hearing Technologies': 5,
#          'MGMT3D': 2,
#          'BLST Operating Company LLC': 13,
#          'Gava Talent': 1,
#          'Elutions': 13,
#          'Varen Technologies': 1,
#          'Mountain America Credit Union': 1,
#          'Nav': 6,
#          'Fortitude Re': 1,
#          'FedEx Services': 4,
#          'Lirio': 4,
#          'Ennsee Technologies': 1,
#          'DANE Talent Connections': 1,
#          'Event Dynamic': 3,
#          'Sekon': 1,
#          'Capital One - US': 2,
#          'PCS Software': 3,
#          'Apgar Consulting': 1,
#          "Sam's Club (a division of Walmart)": 1,
#          'Fenix Group Inc': 8,
#          'NextXAP': 2,
#          'BlackHorse Solutions Inc': 2,
#          'ATA-LLC': 1,
#          'Resolution Bioscience': 10,
#          'Glowforge': 2,
#          'Chinook Therapeutics': 2,
#          'BE Group': 1,
#          'ClinChoice': 3,
#          '9Rooftops': 5,
#          'Ascent Health': 1,
#          'Triax Technologies': 1,
#          'ReefPoint Group': 2,
#          'Insight Global Client - Confidential': 1,
#          'Winnebago Industries Inc': 3,
#          'Dearborn Group': 1,
#          'Allied Tube and Conduit Corporation': 1,
#          'Gras Savoye': 18,
#          'Bobby E. Wright Comprehensive Behavioral Health': 1,
#          'Thought Storm LLC': 5,
#          'Constant Group': 1,
#          'Cogensia': 1,
#          'Darwin AI': 5,
#          'BuzzClan LLC': 4,
#          'ITA Group Inc': 4,
#          'Johnson County Iowa': 1,
#          'Intone Networks': 4,
#          'Eldon C. Stutsman': 2,
#          'Blue Chip Hiring': 1,
#          'S&S Employment Partners': 1,
#          'Found Professionals': 1,
#          'Lunavi': 1,
#          'Strategic Health Partners / MAK Anesthesia': 1,
#          'DataLink Fund Solutions': 2,
#          'VITUS Search Group': 2,
#          'Orange Care Group': 1,
#          'DHL eCommerce': 4,
#          'CONTINENTAL FINANCE COMPANY': 6,
#          'Convey Health Solutions is Hiring Now': 1,
#          'DFS': 1,
#          'Anovaa': 1,
#          'TPI': 2,
#          'RSL Strategies': 3,
#          'InSite': 1,
#          'International AntiCounterfeiting Coalition (IACC)': 1,
#          'Association for Enterprise Opportunity': 1,
#          'Cayuse Holdings': 4,
#          'Enovational': 1,
#          'Compass Solutions LLC': 4,
#          'OCT Consulting LLC': 9,
#          'R3 Education Inc.': 1,
#          'Nan McKay & Associates': 1,
#          'Irby Electric Supply': 3,
#          'BVM Technology Associates Inc': 3,
#          'Budderfly Inc': 1,
#          'Artemis Consulting': 3,
#          'Cloud Peritus': 1,
#          'Digital Dhara': 26,
#          'VingsTech': 1,
#          'Fisker Inc': 2,
#          'Blue Moon Digital': 4,
#          'McFadden-Dale Hardware': 2,
#          'Swift Engineering Inc. www.swiftengineering.com': 1,
#          'Managed Service Provider': 2,
#          'First Western': 1,
#          'Craig Hospital': 2,
#          'Nucleusteq': 2,
#          'Na': 14,
#          'Copperstate Farms': 1,
#          'Community Health Centers of Arkansas': 1,
#          'TLI | Riverside Transport Inc': 3,
#          'ParityFactory LLC': 2,
#          'Bestway USA Inc.': 1,
#          'Transplace': 2,
#          'V-Tech Solution': 1,
#          'Hill Technical Solutions': 3,
#          'Zen3 Infosolutions private limited': 3,
#          'PDI': 4,
#          'Florida Institute for Community Studies (FICS)': 1,
#          'CoreAxis Consulting': 1,
#          'cloudteam': 4,
#          'RISE IT SOLUTIONS': 1,
#          'BurgerFi International LLC': 1,
#          'Confidential': 14,
#          'Exzac': 7,
#          'INSIGHTEC-US': 1,
#          'Lynx (Central Florida Regional Transportation Authority)': 1,
#          'RMS | Rooms To Go': 1,
#          'Shubhtech': 3,
#          'Anthology Inc.': 3,
#          'Frank Winston Crum Insurance': 3,
#          'MATRIX Resources': 3,
#          'Business Software (BSI)': 1,
#          'Panam Consulting': 3,
#          'Internap Holding LLC': 1,
#          'Atrium Works LLC': 8,
#          'Mohawk Global Logistics Corp': 2,
#          'Peachtree Hospitality Management': 2,
#          'Updater': 3,
#          'Matrss': 1,
#          'TekPal': 5,
#          'Production Facility': 2,
#          'THE ALEXANDER GROUP INC': 3,
#          'Acosta - Corporate': 3,
#          'Rev.io': 2,
#          'OMNY': 1,
#          'HatchWorks Technologies': 1,
#          'Weboptimix': 3,
#          'Castle Credit': 1,
#          'Allvue Systems': 4,
#          'WellBe Senior Medical': 2,
#          'Wellbe Senior Medical': 4,
#          'PROMARKETEXCHANGE': 2,
#          'BACloudSystems': 3,
#          'Home Partners of America Inc': 2,
#          'ELITE DENTAL PARTNERS L': 1,
#          'Reverb': 4,
#          'iknowvate technologies': 34,
#          'Kalven Technologies.Inc': 2,
#          'AM Trace': 1,
#          'DATOVY.INC': 1,
#          'at HomeLight': 1,
#          'Focus Talent Group': 3,
#          'iLink Systems Inc.': 2,
#          'RealDefense': 1,
#          'DB Engineering & Consulting USA Inc.': 2,
#          'Millennial Home Lending': 1,
#          'GoWithFusion.com': 1,
#          'Nevro Corp.': 3,
#          'Mighty Networks': 1,
#          'GSV TECH INC': 2,
#          'Brii Biosciences': 2,
#          'sanfrancis': 1,
#          'Accounting & Finance Professionals': 1,
#          'Enquero Inc': 10,
#          'Akshaya Inc': 3,
#          'Vettanna': 2,
#          'California Water Service Group (CWSG)': 1,
#          'San Diego State University - Translational Emotion Neuroscience & Development Laboratory': 1,
#          'Colsh Consultants': 3,
#          '3I Associates': 2,
#          'AgileOC': 1,
#          'Blueprint Test Preparation': 1,
#          'Therabody': 1,
#          'Sequoia Foundation': 1,
#          'Cloudinfraspecs': 6,
#          'Diverse Systems Group LLC': 1,
#          'Improvix Technologies': 4,
#          'US Department of Education': 17,
#          'Strategic Insight LTD': 4,
#          'Concentric Energy Advisors': 4,
#          'Enlightened Inc.': 3,
#          'ADVANCED MANAGEMENT STRATEGIES GROUP(AMSG)': 7,
#          'Kaizen Dynamics': 11,
#          'BARROW CONSULTING INC': 4,
#          'WenovatIQ LLC': 1,
#          'Washington Area Community Investment Fund': 1,
#          'TEAMGOV INC': 2,
#          'Capitaltechsolutions Inc': 5,
#          'Family Support Services Of North Flo': 1,
#          'The Bug Bite Thing': 1,
#          'Nectar Consulting': 1,
#          'Special Operations Warrior Foundation': 1,
#          'Q Link Wireless': 2,
#          'Fiduciary Outsourcing': 1,
#          'Kcas Bioanalytical & Biomarker Services': 5,
#          'RTI | Riverside Transport Inc': 3,
#          'Optimally': 1,
#          'Bauer Hockey (Indianapolis)': 4,
#          'Supportive Community Innovations-': 11,
#          'Kittle Property Group': 1,
#          'AmeriQual Foods': 1,
#          'Franciscan Corporate': 3,
#          'aFit Staffing': 1,
#          'Vestil Manufacturing Corporation': 2,
#          'eimagine': 5,
#          'Vespa Group': 2,
#          'PRECISIONxtract': 4,
#          'Onebridge': 8,
#          'American United Life Ins Co': 2,
#          'ProAxis Consulting': 8,
#          'nc': 2,
#          'InfoArmor Inc': 1,
#          'ProdAnalytics': 2,
#          'StrongMind Inc.': 1,
#          'DeNOVO Solutions': 2,
#          'Billtrust Careers': 11,
#          'Envision Healthcare Systems': 1,
#          'Global IT Family': 2,
#          'SSA': 4,
#          'Freshworks': 1,
#          'Otcmarketpro': 2,
#          'Chime': 8,
#          'Procurement IQ': 1,
#          'Banking and Finance Professionals': 1,
#          'Medable': 4,
#          'Electrical Source Holdings': 2,
#          'Arbor Financial Systems': 6,
#          'Oneida ESC Group': 3,
#          'PARACHUTE HOME': 1,
#          'CapitalPlanHoldings': 2,
#          'Walt Disney Direct-to-Consumer and International': 4,
#          'Kate Farms': 3,
#          'Winwire Technologies': 3,
#          'University Enterprises Corporation at CSUSB': 1,
#          'Prealize Health': 2,
#          'Luma Health': 1,
#          'Triune Infomatics Inc': 3,
#          'Boston Pioneer Solutions': 2,
#          'Who... a staffing company': 3,
#          'Quick Release_': 6,
#          "Land O'Lakes (Temporary)": 1,
#          'UNCOMN': 2,
#          'Missouri Primary Care Association': 2,
#          'Cash App': 14,
#          'Data Bridge': 3,
#          'EVERSANA-US': 5,
#          'EccoSelect': 1,
#          'Orange EV': 3,
#          'Amply Media': 22,
#          'Epathusa INC': 5,
#          'ePATHUSA Inc': 8,
#          'Epathusa': 2,
#          'Rhodes 101 Convenience Stores': 1,
#          'NewWave HQ': 3,
#          'MAG Areospace': 2,
#          'Emocha Mobile Health Inc': 1,
#          'The Office of Research Integrity': 1,
#          'Phyton Advisors': 9,
#          'Pinnacle Alliances': 7,
#          'Adventist HealthCare': 1,
#          'Intulog': 1,
#          'Swenson Consulting': 1,
#          'Elign Consulting': 37,
#          'Washington County (MN)': 1,
#          'Upton Hill': 2,
#          'Hueman Private Investment Talent Solutions': 1,
#          'BlueChip Financial': 3,
#          'Fidelity Bank MN': 1,
#          'Polaris Inc.': 6,
#          'Datawave Technologies': 3,
#          'VXForward LLC': 1,
#          'iAffiliate Management': 6,
#          'Genoa Employment Solutions Inc': 1,
#          'PL': 5,
#          'T3W Business Solutions Inc': 6,
#          'Centria Pediatric Nursing': 2,
#          'MKB Holdings': 5,
#          'Raland Compliance Partners': 3,
#          'Blue Cross Blue Shield of Michigan': 1,
#          'Trinity Health - IHA': 1,
#          'Pricesenz': 15,
#          'Synergent': 1,
#          'GM Financial': 1,
#          'Arkatechture': 3,
#          'Avantor Services': 2,
#          'Aciron Consulting': 2,
#          'Software Experts': 1,
#          'Pembroke & Co.': 2,
#          "Southern Glazer's Wine And Spirits Of Texas": 2,
#          'Pearson': 2,
#          'S&K Mission Support': 1,
#          'Winston Industries LLC': 2,
#          'Motherson Sumi Infotech & Designs': 2,
#          'Confidential healthcare company': 1,
#          'Kani Solutions Inc.': 14,
#          'Net2Aspire LLC': 4,
#          'Camp Systems International': 1,
#          'Abtsus LLC': 4,
#          'Nanda Technologies': 7,
#          'Interpublic Group (IPG)': 1,
#          'Accede LLC': 5,
#          'Ahold Delhaize Global Support': 4,
#          'SunTech Medical': 1,
#          'Intelerad': 1,
#          'Kepler Team': 1,
#          'VCA Solutions': 2,
#          'IS2': 2,
#          'SS': 1,
#          'Calculated Hire': 1,
#          'Fulcrum Research Group': 2,
#          'Raps Consulting Inc.': 6,
#          'Sage IT': 6,
#          'Talent tigers': 6,
#          'Clinpharma Clinical Research LLC': 2,
#          'Iconic Technology Group': 2,
#          'Systechcorp Inc': 3,
#          'Pycube Inc': 1,
#          'Ammon Analytical Laboratory LL': 1,
#          'Katalyst Healthcares & Life Sciences': 9,
#          'Advanced Technology Consulting Service (ATCS)': 2,
#          'Datasys America': 1,
#          'Crackajack Solutions': 3,
#          'V-Tech Solutions': 1,
#          'Information Consulting Services of Delaware Valley': 2,
#          'Vayyusoft LLC': 1,
#          'HaystackID': 1,
#          'Olympus Corporation of the Americas': 17,
#          'OFSS': 3,
#          'MedMinder': 1,
#          'Cimpress/Vistaprint': 13,
#          'PartRunner': 3,
#          'TR3 Solutions': 4,
#          'DAtec': 16,
#          'The Cervantes Group': 1,
#          'LC': 12,
#          'ibrain Technologies Inc': 6,
#          'Claremont Companies LLC': 1,
#          'Tekla Research': 16,
#          'TBS Solutions LLC': 1,
#          'Mid Shore Council on Family Violence': 1,
#          'UM Rehabilitation & Orthopaedic Institute': 2,
#          'Vision': 14,
#          'University of Maryland Capital Region': 4,
#          'Center for the Study of Traumatic Stress': 2,
#          'Business Staffing Solution': 6,
#          'Alliant Cooperative Data Solutions': 3,
#          'Stupell Industries': 1,
#          'Police and Fire Federal Credit Union': 1,
#          'SHR Talent': 7,
#          'Next Generation Recruitment and Staffing Agency': 2,
#          'Vervent Inc': 3,
#          'CGF CounselGroupFrankfurt': 2,
#          'Palmetto State Armory L': 1,
#          'Monro Inc.': 2,
#          'Black Systems LLC': 6,
#          'New York City Metro Regional Center': 2,
#          'SBS Info Systems': 1,
#          "US Family Health Plan @ St. Vincent's Catholic Medical Center": 2,
#          'root liquids': 8,
#          'Jerneltechcorp': 7,
#          'PI': 3,
#          'New York City Department: HIV EPI & Field Svces | Location: QUEENS | Business Unit: DEPT OF HEALTH/MENTAL HYGIENE | Posted Date: 01/08/2021': 1,
#          'Big Apple Group': 2,
#          'The Giorgi Companies': 2,
#          'Steep Hill Pennsylvania': 3,
#          'Iscientia': 2,
#          'Doyelstown Health': 3,
#          'Brandstein Family Services': 2,
#          'ClinChoice Inc': 10,
#          'Capital BlueCross': 1,
#          'Anexinet Job Board': 1,
#          'Ricoh': 1,
#          'Luca and Danni': 1,
#          'FlairTech Solutions LLC': 7,
#          'Commonwealth of Pennsylvania': 1,
#          'Iscientiaus': 14,
#          'MiTek Inc.': 1,
#          'Careers Inc.': 1,
#          'TMNA Services LLC': 3,
#          'Eurofins USA BioPharma Services': 5,
#          'Clinical Score': 19,
#          'Multiple Client Opportunities': 1,
#          'Cambia Health Solutions': 2,
#          'Employment Department': 2,
#          'The Mom Project': 12,
#          'Majoris Health Systems': 1,
#          'Cora Systems': 1,
#          'Dutchie': 2,
#          'LDF Support Group Inc': 1,
#          'Penobscot Bay Media LLC': 1,
#          'Integrated Data Services Inc.': 14,
#          'Vantage Point Logistics': 1,
#          'The Ettain Group': 3,
#          'TP Resources': 3,
#          "Tra'Bian Enterprises": 9,
#          'Homeworks Logistics LLC': 2,
#          'The Scotts Miracle-Gro Company': 1,
#          'American Business Solutions Inc': 4,
#          'Marquee Enterprises Inc': 1,
#          'Ohio State University Medical Center': 6,
#          'IT-Strat': 3,
#          'Blackcomb Consultants': 1,
#          'State Bank': 4,
#          'Vertiv Co.': 1,
#          'IGS Energy': 2,
#          'N2Y LLC': 1,
#          'Sciata': 1,
#          'a ': 4,
#          'NCP Finance Ohio LLC': 1,
#          'Shrimpy': 2,
#          'The Greentree Group': 1,
#          'Purple Drive Solution': 1,
#          'HireTech Group': 2,
#          'TREW LLC': 4,
#          'Clearcover': 12,
#          'Equitable Advisors': 1,
#          'GK Properties': 1,
#          'Vaizva': 1,
#          'IDology': 3,
#          'Sionic': 5,
#          'CloudServiceTek': 2,
#          'US Systems LLC': 1,
#          'NICE Actimize': 6,
#          'Flock Safety': 13,
#          'Lavoro Group': 2,
#          'New York City Department: BA/QA - BUSINESS ANALYST | Location: BROOKLYN | Business Unit: DEPT OF INFO TECH & TELECOMM | Posted Date: 01/11/2021': 1,
#          'Indeed Flex': 1,
#          'Dorabot Inc.': 8,
#          'Adwait': 6,
#          'Solis Mammography/ Washington Radiology': 4,
#          'Dignitas Technologies LLC': 2,
#          'FinTrust Search Group': 1,
#          'Darkblade Systems Corporation': 22,
#          'Army Houston Recruiting Battalion': 8,
#          'IQ-EQ': 1,
#          'BuzzBallz': 1,
#          'GOIN': 6,
#          'Kaligia Biosciences': 2,
#          'Better Business Bureau Serving the Heart of Texas': 1,
#          'Microsolutiontek': 4,
#          'Pv': 1,
#          'Resolve Tech Solutions Inc.': 1,
#          'Aezion In': 1,
#          'HealthMark Medical Group': 1,
#          'Tarrant Regional Water District': 1,
#          'The Davis Group & Alpharetta Construction Company': 5,
#          'Syeta Inc': 8,
#          'GlobalSoftSolution': 1,
#          'Gratiture Solutions': 1,
#          '[x]cube LABS': 3,
#          'Scaleapi': 5,
#          'Kensho': 7,
#          'CytoVeris Inc.': 1,
#          'Divish LLC': 2,
#          'Snap IT Solutions': 3,
#          'MNK INFOTECH INC': 2,
#          'Ironclad Technnology Services': 3,
#          'Relias Consulting Group': 1,
#          'Nemean Solutions': 1,
#          'Vichara': 1,
#          'Gotham Enterprises': 9,
#          'Raventek Solution Partners LLC': 2,
#          'SMARTECH-CSI.com': 4,
#          'Canoo': 5,
#          'Freenome Holdings': 17,
#          'NextRoll': 4,
#          'Bold Commerce': 1,
#          'Embark Trucks': 1,
#          'HKMS': 1,
#          'ABC INFORMATION TECHNOLOGY GROUP': 1,
#          'New Level Recruiting': 1,
#          'SafeGraph': 6,
#          'Pictor Labs': 3,
#          'Tri-Starr Technology': 2,
#          'First Notch Technology LLC': 23,
#          'LP': 10,
#          'Denver Health': 2,
#          'Attainia Inc.': 1,
#          'Data Gumbo': 1,
#          'TuSimple': 75,
#          'InfluxData': 5,
#          'Alliant Insight': 2,
#          'AccelOne': 1,
#          'Kinesso': 7,
#          'Poseidon Brands Inc.': 1,
#          'Medical Director Services PC': 4,
#          'REEL USA': 1,
#          'Lopez Negrete': 1,
#          'ConnectedX Inc.': 7,
#          'ACS Solutions': 2,
#          'Infinites HR Services': 3,
#          'Datamark Careers': 2,
#          'Health Fidelity': 4,
#          'Freenome': 5,
#          'Lagomaj Capital': 1,
#          'Honda Research Institute USA': 7,
#          'Neighborhood Defender Service': 2,
#          "The Farmer's Dog": 4,
#          'Nelson Interactive': 1,
#          'New York City Department: Mold Asmt & Remediation | Location: QUEENS | Business Unit: NYC HOUSING AUTHORITY | Posted Date: 01/14/2021': 1,
#          'The Cohen Management Group': 1,
#          'Faire': 11,
#          'GoFundMe': 2,
#          'CrowdRise': 2,
#          'LINE Plus corporation': 1,
#          'Specright Inc.': 6,
#          'Legalist': 31,
#          'New York State Psychiatry Institute': 2,
#          'New Visions Central Office': 1,
#          'Ro': 1,
#          'Bertrandt': 3,
#          'Chainalysis': 1,
#          'Wine Enthusiast Companies': 1,
#          'Addepar': 6,
#          'Transcend Digital': 2,
#          'Praxinet': 2,
#          'New York City Department: Lead Hazard Control Department | Location: QUEENS | Business Unit: NYC HOUSING AUTHORITY | Posted Date: 01/13/2021': 2,
#          'Ampere Computing': 6,
#          'NYC IT INC': 1,
#          'Toll International LLC': 10,
#          'New York City Department: Fiscal and Budget Planning | Location: BROOKLYN | Business Unit: DISTRICT ATTORNEY KINGS COUNTY | Posted Date: 01/13/2021': 1,
#          'Syracuse Haulers Waste Removal Inc.': 1,
#          'Vimeo': 6,
#          'DataCatalyst LLC': 3,
#          'SimilarWeb': 5,
#          'DIANAVI Corporation': 3,
#          'Sila Nanotechnologies': 1,
#          'China Telecom Americas Corporation': 2,
#          'MRM': 1,
#          'Happify Health': 1,
#          'Spine Media': 6,
#          'SiFive Inc': 1,
#          'UnitedMasters': 2,
#          'Layer 7 Data Solutions': 41,
#          'Route': 9,
#          'Databricks': 22,
#          'Starkflow': 1,
#          'Unlearn.AI': 8,
#          'on': 1,
#          'Infolob': 23,
#          'RFS Group': 1,
#          'JetFuel': 4,
#          'General Vision Services': 1,
#          'Kharon': 2,
#          'Cape Analytics': 5,
#          '5 Elements Techno Services': 1,
#          'The Mitchell Madison Group': 1,
#          'Calico': 3,
#          'ThirdEye Data': 1,
#          'Palo Verde Consulting': 4,
#          'Nivid Technologies': 1,
#          'SoundHound Inc.': 4,
#          'SPECK DESIGN': 1,
#          'MartinFederal': 1,
#          'Tech IT Solution': 2,
#          'Wipro LTD': 3,
#          'Virginia Hospital and Healthcare Association': 2,
#          'Trinity Glass International Inc': 1,
#          'American Medical Facilities Management': 4,
#          'Alpha Omega Integration': 2,
#          'GreyscaleAI': 1,
#          'Kruger Family Industries': 1,
#          'Miso Robotics': 6,
#          'Remedy Analytics': 1,
#          'Enerpac Tool Group': 2,
#          'Dash technologies': 3,
#          'Hivemapper': 2,
#          'Info-Pro Lender Services': 3,
#          'The Bay Family of Companies': 1,
#          'LiveFaculty': 1,
#          'Comfy': 2,
#          'Fishline Food Bank and Comprehensive Services': 2,
#          'Biglynx': 1,
#          'Cribl Inc.': 1,
#          'Amitree': 1,
#          'Convex': 1,
#          'City of Seattle': 3,
#          'Shape (ShapeScale)': 1,
#          'Outreach': 9,
#          'BillionToOne': 1,
#          'Foverobrains': 1,
#          'Rational': 5,
#          'Constructors Racing Group': 2,
#          'Gocool Inc': 2,
#          'LYT': 1,
#          'Martek Global Services Inc.': 4,
#          'VASS': 7,
#          'Karius': 10,
#          'ProSource360': 1,
#          'JDSAT': 7,
#          'CesiumAstro': 8,
#          'Orbital Sidekick': 2,
#          'PTEC Solutions': 1,
#          'Transform Data': 4,
#          'TENICA and Associates LLC': 7,
#          'Virginia Div of Institutions': 2,
#          'iQuasar LLC': 10,
#          'Virginia Dept of Taxation': 4,
#          'Springboard': 1,
#          'Learnship Networks GmbH': 1,
#          'EPS Inc.': 2,
#          'Development InfoStructure': 6,
#          'Gravy Analytics': 2,
#          'Tesla': 1,
#          'Creative Systems and Consulting': 2,
#          'Park Computer Systems Inc': 5,
#          'Morton': 15,
#          'Navagis': 1,
#          'BOEING': 1,
#          'FourKites': 2,
#          'Potomac Management': 3,
#          'Jettison': 7,
#          'Arena Technologies': 1,
#          'Arena Technoloiges': 3,
#          'United Airlines Inc.': 1,
#          'Mesh Plus Plus': 13,
#          'Belden Universal (via FactoryFix.com)': 4,
#          'HN Consulting': 1,
#          'Virginia Dept of Housing and Comm Dev': 1,
#          'Evercommerce': 6,
#          'Big Ladder Software': 1,
#          'TrendLogic Solutions': 1,
#          'ViroTech Solutions': 1,
#          'AMP Robotics': 8,
#          'The Admiral James J. Carey Foundation': 1,
#          'Cipher Skin Inc': 2,
#          'Transformation Systems Inc.': 1,
#          'Hitachi Vantara Corporation': 13,
#          'SAGE Black': 8,
#          'SAGE Black Consulting & Contracting LLC': 15,
#          'DNP - Deseret News': 1,
#          'ChatFunnels': 1,
#          'Artifact': 1,
#          'REscan': 2,
#          'UAM Division of Hyundai Motor Group': 5,
#          'LeanTaaS': 3,
#          'Lodestone': 6,
#          'Workday': 1,
#          'PathAI': 8,
#          'MinTech Agency': 1,
#          'Oakland Community Health Network': 2,
#          'Balance Technology Inc.': 1,
#          'Giant Media': 6,
#          'Esys': 1,
#          'Man Group': 2,
#          'EBW Electronics': 2,
#          'EnvisionTEC': 6,
#          'SFL Scientific': 9,
#          'Alldus': 41,
#          'Perceptive Automata': 17,
#          'Particle': 1,
#          'Lyndra Therapeutics': 1,
#          'Mölnlycke': 1,
#          'HighByte': 1,
#          'Prosync': 9,
#          'iFrog Marketing Solutions': 2,
#          'Elenchus Technologies': 1,
#          'IAMUS Consulting': 11,
#          'NIH-NCBI': 2,
#          'Bowler Pons Solutions Consultants': 1,
#          'Harness.io': 3,
#          'iZOTOPE': 3,
#          'Co': 3,
#          'Mersen USA Holding Corp': 1,
#          'Inkbit': 1,
#          'Signifier Medical Technologies': 2,
#          'Titan Advanced Energy Solutions': 1,
#          'Delsys Incorporated': 2,
#          'Motional': 62,
#          'ANDURIL INDUSTRIES': 7,
#          'VulcanForms': 16,
#          'Eagle6 Software': 2,
#          'Tec Air LLC': 2,
#          'Canopy': 1,
#          'Mandolin': 1,
#          'Princeton University': 1,
#          'Swan Island Networks': 1,
#          'Armorblox': 1,
#          'Low Latency Recruiting': 1,
#          'SingleStore': 4,
#          'Frontdoor': 60,
#          'ASTUTE': 1,
#          'TownePlace Suites': 1,
#          'Geauga County Engineer': 1,
#          'Michael Page': 2,
#          'Bitfocus': 4,
#          'Genesis Research': 1,
#          'Raditech LLC': 4,
#          'DUST Identity': 6,
#          'Career Developers': 7,
#          'Stratifyd': 1,
#          'Infinia ML': 6,
#          'AURA TECHNOLOGIES LLC.': 15,
#          'Squirro': 1,
#          'EnergyHub': 22,
#          'CatapultX': 1,
#          'BCGDV': 2,
#          'Kaia Health Software GmbH': 2,
#          'treeleaf.ai': 4,
#          'PostProcess Technologies': 1,
#          'Oden Technologies': 1,
#          'The Fu Foundation School of Engineering & Applied Science of Columbia University': 1,
#          'Altonomy': 1,
#          'This is Alice': 1,
#          'Zip': 2,
#          'Unqork': 1,
#          'HODINKEE': 1,
#          'Remesh': 7,
#          'Borassus Infotech': 3,
#          'Simon Data': 11,
#          'Socure': 9,
#          'Motion Control Corporation': 1,
#          'A ': 2,
#          'Kfilarski Staff': 2,
#          ...})

# %%
list_of_us_codes = ['AK', 'AL', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'GU', 'HI',
                    'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MP',
                    'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI',
                    'SC', 'SD', 'TN', 'TX', 'UM', 'UT', 'VA', 'VI', 'VT', 'WA', 'WI', 'WV', 'WY']
dd = droped_dup_data[droped_dup_data.state.isin(list_of_us_codes)]
dd.shape
# Out:
# (223719, 8)

# %%
Counter(dd.company)
# Out:
# Counter({'Veterans Enterprise Technology Solutions': 4,
#          'Brooksource': 79,
#          'Premium Retail Services': 26,
#          'Centene Corporation': 463,
#          'Myticas Consulting': 33,
#          'SPECTRUM': 267,
#          'Amgen': 80,
#          'The McIntyre Group': 1,
#          'Continental Finance Company, LLC': 4,
#          'SMP Pharmacy Solutions': 1,
#          'Knowledge Management, Inc': 3,
#          'firstPRO 360': 5,
#          'Agilon Health': 4,
#          'Advantage Resourcing': 56,
#          'PetIQ': 14,
#          'Datamatics Global Services Inc': 16,
#          'DBO Technologies LLC.': 7,
#          'Weiman Products LLC': 2,
#          'Acorn Health of Illinois LLC': 3,
#          'SMITH': 52,
#          'MJ Holding Company LLC': 2,
#          'NTT DATA Corporation': 42,
#          'Recruiting Solutions': 4,
#          'Cornerstone Business Advisory Group LLC': 1,
#          'Springfield Clinic': 4,
#          'AETNA': 80,
#          'SpiderRock': 1,
#          '#TeamGoHealth': 113,
#          'Catholic Charities of the Archdiocese of Chicago': 2,
#          'Astellas Pharmaceuticals': 6,
#          'Photon': 37,
#          'Larsen & Toubro Infotech Limited': 20,
#          'Motorola Solutions': 137,
#          'Demar Direct': 1,
#          'Wintrust Financial Corporation': 13,
#          'Kellogg Company': 16,
#          'US Department of the Air Force': 1075,
#          'Discover Financial Services': 169,
#          'CDK Global': 55,
#          'The University of Chicago': 63,
#          'Exelon Corporation': 216,
#          'Moorecroft Systems, Inc.': 4,
#          'HomeX': 4,
#          'InSight + Regroup': 1,
#          'AbbVie': 145,
#          'The William Everett Group': 2,
#          'Teriger': 3,
#          'SPINS, LLC': 7,
#          'Cook County Offices Under the President': 6,
#          'Camelot Illinois': 6,
#          'Beyond Finance': 17,
#          'Aspire Global Tech': 12,
#          'Northwestern University': 64,
#          'Evolent Health': 26,
#          'SSI': 77,
#          'Northwestern Memorial Healthcare': 6,
#          'RGAL': 8,
#          'Draper and Kramer': 1,
#          'Compeer Financial': 2,
#          'Bosch Group': 71,
#          'WellCare': 31,
#          'Dovenmuehle': 12,
#          'Saggezza': 11,
#          'CSL Behring': 18,
#          'Ryan Specialty Group': 4,
#          'BD': 86,
#          'Decisive BI': 1,
#          'Signode Industrial Group': 3,
#          'City of Chicago': 3,
#          'Anomalix': 3,
#          'Pon Equipment AB': 14,
#          'US Department of Veterans Affairs': 546,
#          'US Department of the Army': 966,
#          'ZLLIUS': 16,
#          'Caterpillar': 162,
#          'Digital Dhara': 45,
#          'Capstone Corporation': 22,
#          'Baxter': 5,
#          'Chicago Transit Authority': 10,
#          'Midwestern IT': 51,
#          'iVinci Health': 17,
#          'Senee IT Consulting, LLC': 2,
#          'Micron': 357,
#          'Amazon.com Services LLC': 7172,
#          'Kuder, Inc.': 2,
#          'AmerisourceBergen': 67,
#          'DLL': 8,
#          'Matrix Resources': 206,
#          'TeamSoft, Inc - a Peoplelink Company': 25,
#          'Palmer Group': 4,
#          'State of Iowa Talent Gateway': 27,
#          'Sabre Industries Inc': 10,
#          'DLL Group': 7,
#          'Renewable Energy Group Inc': 6,
#          'GreatAmerica Financial Services': 3,
#          'Atlantic Coca-Cola Bottling Company': 1,
#          "Casey's General Stores": 16,
#          'First Hawaiian Bank': 13,
#          'Imua Family Services': 1,
#          'County of Hawaii': 2,
#          'Research Corporation of the University of Hawaii': 3,
#          'US Department of the Navy': 980,
#          'Voya Financial': 28,
#          'Tosca': 3,
#          'Columbus Consolidated Government': 1,
#          'RELX Group': 87,
#          'FIS Global': 156,
#          'Sharecare Inc': 15,
#          'Centers for Disease Control and Prevention (CDC)': 10,
#          'Kani Solutions': 19,
#          'New Signature': 7,
#          'Cohesive Solutions': 4,
#          'Alaka`ina Foundation Family of Companies': 38,
#          'PossibleNow': 1,
#          'DXC': 184,
#          'Ardmore Consulting Group': 1,
#          'Transportation, Georgia Department of - GDOT': 3,
#          'Centers for Disease Control and Prevention': 95,
#          'Epathusa INC': 19,
#          'The Home Depot': 232,
#          'Porsche Financial Services Inc.': 1,
#          'Fischer Homes': 5,
#          'Technology Authority, Georgia - GTA': 1,
#          'Northrop Grumman': 379,
#          'TJFACT, LLC': 15,
#          'GEORGIA-PACIFIC': 13,
#          'Philips': 41,
#          'Cox Automotive': 81,
#          'Delta Dental': 73,
#          'Ervin Cable Construction, LLC': 15,
#          'Safe-Guard Products International, LLC': 20,
#          'CharterUP': 11,
#          'i4 Insurance Talent': 2,
#          'DTCC': 33,
#          'Wellcare': 8,
#          'PrudentRx LLC': 1,
#          'CITI': 130,
#          'Webstaurant Store, Inc.': 29,
#          'Pozent Corporation': 1,
#          'Martin County': 1,
#          'Hillsborough County': 5,
#          'Trulieve': 2,
#          'TSL Consulting Pvt. Ltd': 1,
#          'Total Insurance Brokers': 1,
#          'Complete Health': 5,
#          'Collier County, FL': 9,
#          'Frontier Communications': 31,
#          'Andromeda Systems Incorporated': 7,
#          'KPMG': 787,
#          'City of Tampa': 3,
#          'CyberCoders': 696,
#          'Virtusa': 116,
#          'Intone Networks Inc': 8,
#          'Miami Cancer Institute at Baptist Health': 2,
#          'State of Delaware': 68,
#          'DuPont': 14,
#          'Adecco': 21,
#          'AstraZeneca': 250,
#          'JP Morgan Chase': 190,
#          'Strategic Insight LTD': 13,
#          'Clarus Group': 1,
#          'NFF Inc': 8,
#          'US Department of Homeland Security': 632,
#          'Jamison Professional Services Inc': 1,
#          'AARP': 12,
#          'US Department of the Interior': 182,
#          'US Department of Housing and Urban Development': 183,
#          'Incapsulate': 3,
#          'Redhorse Corporation': 36,
#          'Guidehouse': 689,
#          'The LDM Group': 3,
#          'Dignari': 8,
#          'Marieke Consulting, Inc.': 1,
#          'Total Systems Technologies Corporation': 5,
#          'Syntelligent Analytic Solutions, LLC': 27,
#          'NikSoft Systems Corp.': 21,
#          'Serco North America': 57,
#          'WenovatIQ LLC': 1,
#          'Salient CRGT, Inc': 77,
#          'US Other Agencies and Independent Organizations': 391,
#          'Planet Technologies': 2,
#          'Bains Consultiing LLC': 7,
#          'MetroStar Systems': 16,
#          'Capgemini Government Solutions': 29,
#          'Universal Service Administrative Company': 19,
#          'Data Trust': 14,
#          'Straitsys': 1,
#          'Republican National Committee': 9,
#          'Systemart LLC': 4,
#          'Liberty Healthcare Corporation': 7,
#          'US Department of Education': 87,
#          'Insight Global': 83,
#          'State of Connecticut - Department of Energy & Environmental Protection': 4,
#          'Kforce': 256,
#          'Henkel': 24,
#          'donato technologies': 3,
#          'CapB InfoteK': 21,
#          'SEMA4': 14,
#          'Cushman & Wakefield': 53,
#          'Ensign-Bickford Industries, Inc.': 1,
#          'Nava Software Solutions LLC': 1,
#          'Symetra': 15,
#          'American Business Solutions Inc.': 1,
#          'Navasoft': 1,
#          'Cogent Infotech': 16,
#          'IBM': 316,
#          'CDC Foundation': 10,
#          'A+E Networks': 5,
#          'Kinsley Group, Inc': 4,
#          'EVERSOURCE': 46,
#          'Cigna': 230,
#          'Travelers': 110,
#          'Alrek': 1,
#          'Medtronic': 117,
#          'EDF Renewables': 8,
#          'Canopy One Solutions, Inc.': 7,
#          'Southern California Edison': 47,
#          'PwC': 64,
#          'Google': 291,
#          'Certus Analytics': 1,
#          'FFF Enterprises, Inc.': 1,
#          'Pacific Gas And Electric Company': 174,
#          'First Republic Bank': 212,
#          'Monster Energy': 7,
#          'County of Santa Clara': 3,
#          'Crowe': 59,
#          'Molina Healthcare': 92,
#          'Department of Industrial Relations': 11,
#          'Ames IT and Numeric Solutions, LLC': 6,
#          'LKimmy Inc.': 2,
#          'UnionBank': 6,
#          'Mobile Integration-Group': 5,
#          'Kendo, a division of LVMH': 3,
#          'Kendo Holdings': 1,
#          'Accrete Hitech Solutions': 1,
#          'Unity Technologies': 49,
#          'VS Media': 23,
#          'Walmart': 383,
#          'Stamps.com': 8,
#          'Linkfire': 1,
#          'Walmart eCommerce': 16,
#          'TemPositions': 3,
#          'Transportation Technology Center, Inc': 2,
#          'Tekruiting': 9,
#          'Vertex Pharmaceuticals': 20,
#          'ACT-1': 2,
#          'First 5 Alameda County': 2,
#          'Jobot': 45,
#          'Robinhood': 20,
#          'SonderMind': 7,
#          'ICF': 125,
#          'WOW!': 20,
#          'JBS USA Food Company': 27,
#          'Physician Health Partners, LLC': 4,
#          'Boulder County, CO': 4,
#          'ManTech International Corporation': 165,
#          'Front Range Staffing': 1,
#          'NTT DATA Services': 377,
#          'U.S. Bank': 240,
#          'State of Colorado Job Opportunities': 65,
#          'Zayo Group': 24,
#          'US Department of Health And Human Services': 215,
#          'LOCKHEED MARTIN CORPORATION': 599,
#          'Qwinix': 2,
#          'Arrow Electronics': 49,
#          'Vail Resorts': 25,
#          'JJR Solutions': 10,
#          'Bross Group': 3,
#          'AORN': 1,
#          'Builders FirstSource': 11,
#          'Empower Retirement': 28,
#          'World Wide Technology, Inc.': 10,
#          'Spectrum': 308,
#          'Silicon Valley Bank': 35,
#          'Maricopa County, AZ': 11,
#          'IT': 4,
#          'vtech Solutions': 11,
#          'Rickley Consulting Partners, LLC': 1,
#          'CVS Health': 589,
#          'Corbins Electric': 3,
#          'PayPal': 343,
#          'MUFG': 127,
#          'State of Arizona': 74,
#          'Prospance Inc': 5,
#          'National Education Partners': 8,
#          'Arizona Public Service': 23,
#          'El Rio Community Health Center': 3,
#          'Scientific Technologies Corporation': 10,
#          'Zenaide': 12,
#          'AZ Dept of Environmental Quality': 1,
#          'Circle K': 24,
#          'Deloitte': 3458,
#          'JOYIN INC': 1,
#          'SimonCRE': 1,
#          'ProAxis Consulting': 9,
#          'P3 Health Partners': 8,
#          'Kollasoft,Inc': 1,
#          'Gould Intelligent': 7,
#          'Arkansas Department of Human Services': 13,
#          'Acosta - Walmart': 1,
#          'Banner Health': 42,
#          'DoorDash': 123,
#          'Murphy USA': 10,
#          'Abbott Laboratories': 170,
#          'Cargill': 61,
#          'Exeter Government Services LLC': 4,
#          'Veteran Staffing Network': 28,
#          'Hargrove Engineers + Constructors': 3,
#          'Logistics Management Institute': 173,
#          'VPD Government Solutions': 6,
#          'SAIC': 343,
#          'a.i. solutions': 2,
#          'SEBA Professional Services, LLC': 1,
#          'Slingshot, Inc.': 1,
#          'Dash Technologies, Inc': 3,
#          'Jetfuel Agency': 40,
#          'DynCorp International LLC.': 17,
#          'Ignite Fueling Innovation': 7,
#          'KBR': 103,
#          'Torch Technologies, Inc.': 32,
#          'Tripoint Solutions': 19,
#          'Auburn University': 15,
#          'AMBE Engineering': 1,
#          'COLSA': 41,
#          'ZUUM Transportation': 1,
#          'Omni2Max': 2,
#          'TekPartners, A P2P Company': 40,
#          'ECS Federal LLC': 115,
#          'An Innovative Cloud Storage Company': 1,
#          'ULTIMATE STAFFING SERVICES': 5,
#          'Lucid Services Group': 1,
#          'Stanford University': 60,
#          'Moser Consulting': 5,
#          'OneMain Financial': 20,
#          'DXC Technology': 16,
#          'American Commercial Barge Line LLC': 1,
#          'St. Vincent, IN': 6,
#          'U.Group': 2,
#          'Covance': 57,
#          'IT EXCEL LLC': 1,
#          'Freedom Mortgage': 150,
#          'AIG': 49,
#          'Indiana University Health': 26,
#          'Do it Best Corp': 8,
#          'Matrix Precise': 4,
#          'GEODIS': 18,
#          'Landmark Health': 5,
#          'CG-VAK': 6,
#          'UsedCardboardBoxes & UCBZeroWaste (UCB)': 3,
#          'Sun Pacific': 1,
#          'Blue Shield of California': 139,
#          'Pacific Life': 21,
#          'GRAIL, Inc.': 11,
#          'CARD - Woodland Hills': 8,
#          'Jam City': 8,
#          'TargetX': 1,
#          'HomeEnergy, Inc.': 2,
#          'Ichor Systems Inc.': 4,
#          'Oracle': 384,
#          'Hoag Memorial Hospital Presbyterian': 29,
#          'Community Health Group': 4,
#          'UC San Diego': 78,
#          'Golden Five': 2,
#          'City National Bank': 25,
#          'USCB INC': 1,
#          'Achieve Beyond Pediatric Therapy & Autism Services': 366,
#          'DocuSign': 60,
#          'Arbor Financial Systems': 30,
#          'CAMERON BELL CORP': 1,
#          'Rootshell INC': 1,
#          'Accend Networks': 1,
#          'US Department of Agriculture': 263,
#          'Lat36': 7,
#          'joulestowatts': 1,
#          'KINGS VIEW': 2,
#          'Transcosmos Sacramento': 2,
#          'Procede Software': 18,
#          'Zigzy': 3,
#          'iNovate Solutions': 6,
#          'Staff Smart': 11,
#          'Salk Institute for Biological Studies': 1,
#          'Housing Authority City of Los Angeles': 3,
#          'MCR, LLC.': 26,
#          'Steelcase': 8,
#          'UCLA': 34,
#          'San Francisco Deparment of Public Health': 4,
#          'ServiceNow': 148,
#          'Visa': 93,
#          'Tandem Diabetes Care, Inc.': 9,
#          'Stage 4 Solutions, inc.': 4,
#          'Bank of the West': 49,
#          'Intellibee Inc': 11,
#          'DCA': 5,
#          'Organifi': 4,
#          'Infotree Service Inc': 49,
#          'BNP Paribas': 58,
#          'Johnson & Johnson Family of Companies': 598,
#          'Twilio': 20,
#          'Milestone Technologies': 25,
#          'US General Services Administration': 76,
#          'Covered California': 4,
#          'Family Health Centers of San Diego': 5,
#          'Advera Health Analytics': 3,
#          'University of California Berkeley': 39,
#          'omega solutions inc': 20,
#          'FAAZ Consulting': 47,
#          'HSTpathways': 2,
#          'Clinicas Del Camino Real, Inc.': 2,
#          'Arize': 1,
#          'Newday Impact Investing': 1,
#          'WeDriveU, Inc.': 1,
#          'Pathways': 4,
#          'Procore Technologies': 25,
#          'The County of Santa Clara - County-Wide Recruitment': 5,
#          'L.A. Care Health Plan': 16,
#          'GENENTECH': 206,
#          'Inspirisys Solutions Limited': 1,
#          'Cornerstone Technology': 3,
#          'Juniper Networks': 58,
#          'Daybreak Games': 4,
#          'McCain Inc.': 1,
#          'Mental Health Association of Orange County': 2,
#          'Tesla': 213,
#          'Lineage Logistics': 8,
#          'Mercury Insurance Services, LLC': 5,
#          'KIA Motors America': 7,
#          'Intuit': 884,
#          'Cameo Consulting Group, LLC': 11,
#          'Marjoree Mason Center, Inc': 3,
#          'Qcentrio, Inc': 1,
#          'Mindsgroup Infotech LLC': 12,
#          'Dun & Bradstreet': 54,
#          'Workforce Logiq': 46,
#          'Slack': 17,
#          'Capio Group': 20,
#          'Illumina': 32,
#          'MT Global US INC': 8,
#          'Vanguard University': 2,
#          'The RealReal': 17,
#          'VSolvit LLC': 8,
#          'Jet Propulsion Laboratory': 26,
#          'County of Riverside': 19,
#          'ESRI, Inc.': 31,
#          'Cisco Systems': 767,
#          'Northrop Grumman Federal Credit Union': 1,
#          'BOEING': 169,
#          'Federal Reserve Bank of Minneapolis': 12,
#          'Integrated Data Services Inc.': 49,
#          'Akshaya Inc': 16,
#          'E-ZEST Solutions Inc': 1,
#          'Bridgewater Consulting Group': 27,
#          'Performance Machine': 2,
#          'Apple': 1241,
#          'Sutter Health': 6,
#          'Department of Food & Agriculture': 2,
#          'Tanisha Systems Inc': 5,
#          'Golden Mask Inc': 11,
#          'Artemis Consulting': 17,
#          'MVM': 17,
#          'TaylorMade Golf Company': 10,
#          'Providence Health & Services': 147,
#          'Global Software Resources': 5,
#          'General Dynamics Information Technology': 406,
#          'University of California, Santa Barbara': 13,
#          'LHI Group': 3,
#          'Liferay, Inc.': 3,
#          'Onyx Government Services,LLC': 17,
#          'US National Aeronautics and Space Administration': 36,
#          'Cherokee Nation Businesses': 52,
#          'ProSphere': 9,
#          'E3 Federal Solutions, LLC': 42,
#          'District Department of Transportation': 1,
#          'Gateway Ventures Inc.': 2,
#          'Analogiks': 4,
#          'Parker Tide Corp.': 4,
#          'MAXIMUS': 78,
#          'CACI': 1035,
#          'LinQuest Corporation': 61,
#          'Cohen Milstein Sellers & Toll PLLC': 1,
#          'US Legislative Branch': 44,
#          'US Department of Energy': 97,
#          'Prescient Edge Federal': 33,
#          'US Department of State': 99,
#          'Mission Essential': 5,
#          'Government of the District of Columbia': 56,
#          'Arc Aspicio': 28,
#          'Dhatronictech': 30,
#          'RER Solutions, Inc': 4,
#          'Attain, LLC': 38,
#          'ACS Group': 38,
#          'Dynamis, Inc': 12,
#          'Networking and Engineering Technologies, Inc.': 2,
#          'Savantage Solutions': 2,
#          'US Department of Transportation': 127,
#          'Carr Properties Services Subsidiary Corp': 1,
#          'US Department of Justice': 96,
#          'World Bank Group': 26,
#          'AE Stategies': 2,
#          'RIVA Solutions, Inc.': 20,
#          'DSSP Consulting, Inc.': 11,
#          'BrickRed Systems': 1,
#          'American Dental Education Association': 1,
#          'RER SOLUTIONS, INC': 7,
#          'Real School Gardens': 1,
#          'Arrow Alliance Industries, LLC': 2,
#          'Attain LLC': 12,
#          'The Consortium, Inc.': 10,
#          'Subsidium': 8,
#          'Citi': 713,
#          'ICG, LLC': 1,
#          'Ultimate Health Plans': 1,
#          'root liquids': 20,
#          'Mercola': 2,
#          'ClearSource': 1,
#          'Trellance': 3,
#          'CoAdvantage': 1,
#          'SafraPay': 3,
#          'USAA': 736,
#          'The Cervantes Group': 57,
#          'Liberty IT Solutions, LLC': 10,
#          'Independent Community Bankers of America': 2,
#          'Miami-Dade County': 3,
#          'University of South Florida': 52,
#          'Barbaricum': 51,
#          'The State of Florida': 209,
#          'Encore Brandz Company': 1,
#          'Unissant': 9,
#          'Insurance Technologies': 1,
#          'The Main Street America Group': 2,
#          'Physicians Regional Health System': 1,
#          'Bluestar Systems Inc.': 12,
#          'TOPSYS IT': 1,
#          'Strategic Resourses, Inc': 1,
#          'NFuzionIT': 1,
#          'Neev Systems LLC': 6,
#          'Special School District': 3,
#          'VT Halter Marine': 2,
#          'Santander Holdings USA Inc': 3,
#          'Leidos': 882,
#          'SoNoted LLC': 1,
#          'Livingston HealthCare': 1,
#          'MiHIN': 27,
#          'Horizontal': 95,
#          'State of Montana': 36,
#          'EDULOG': 13,
#          'SMR SERVICES GROUP, INC.': 1,
#          'Tower Loan': 2,
#          'Orange': 1,
#          'American Century Investments': 10,
#          'Milwaukee Electric Tool Corporation': 21,
#          'Mallinckrodt': 1,
#          'MSI': 4,
#          'Black & Veatch': 5,
#          'Cenlar FSB': 50,
#          'Metro Systems Inc': 2,
#          'Shelter Insurance': 8,
#          'Magellan Health': 69,
#          'Datanalytics, Inc.': 1,
#          'National Association of Insurance Commissioners (NAIC)': 2,
#          'Ameren': 11,
#          'RKV Technologies, Inc.': 6,
#          'Cerner Corporation': 98,
#          'Nanda Technologies': 31,
#          'Catalyte Inc': 4,
#          'MasterCard': 28,
#          'Leading Path Consulting': 6,
#          '391 Financial': 1,
#          'ThreeBridge Solutions': 9,
#          'CoxHealth': 6,
#          'Imperial PFS': 1,
#          'Excelacom': 6,
#          'EXCELACOM INC': 3,
#          'Capgemini': 485,
#          'Infinite Computing Systems': 7,
#          'City of Rochester, MN': 2,
#          'Macalester College': 1,
#          'Thrivent Financial': 51,
#          'Allianz Life': 12,
#          'acs-team': 5,
#          'Be The Match': 18,
#          'Thrivent': 64,
#          'Centriam': 1,
#          'Xcel Energy': 18,
#          'Revel Health': 5,
#          'Elign Consulting': 36,
#          'Arrowhead Engineered Products': 2,
#          'Willis Towers Watson': 117,
#          'UNFI': 80,
#          'UnitedHealth Group': 933,
#          'Advantage Solutions': 40,
#          'Carver County': 1,
#          'Hy-Vee': 47,
#          'LAKSHLUTHER LLC': 1,
#          'Netlink': 1,
#          'Prime Therapeutics': 11,
#          'AccumTech': 3,
#          'Michigan State University': 18,
#          'Rock Central': 24,
#          'Wayne State University': 1,
#          'Home Point Financial Corporation': 29,
#          'Futuresoft IT, LLC': 4,
#          'Quicken Loans': 47,
#          'US Department of Defense': 623,
#          'Meritor': 7,
#          'DETROIT WORKFORCE DEVELOPMENT B': 1,
#          'Key Business Solutions, Inc.': 28,
#          'Infostride': 3,
#          'greenpath, inc.': 5,
#          'RICEFW Technologies, inc': 31,
#          'Egrove Systems Corporation': 1,
#          'Shift Digital': 5,
#          'Evolutyz IT Services': 8,
#          'The Macomb Group': 1,
#          'Ramsoft Systems Inc': 2,
#          'Summit Technologies, Inc': 1,
#          'ePromptus,Inc': 2,
#          'Relapath': 4,
#          'Comerica Bank': 19,
#          'Global Staffing': 4,
#          'Integra Partners': 2,
#          'Maine Center for Disease Control and Prevention': 2,
#          'Arkatechture': 7,
#          'METIS Solutions': 75,
#          'Firebird AST': 8,
#          'ANALYGENCE Inc. (TS/SCI clearance)': 3,
#          'Keller Foundations, LLC': 2,
#          'Monster Lead Group': 1,
#          'Dixon Valve & Coupling Company, LLC': 2,
#          'Johns Hopkins University': 112,
#          'Radiant Infotech': 1,
#          'Harford County, MD': 1,
#          'Medifast, Inc.': 11,
#          'US Department of Commerce': 405,
#          'Arthur Grand Technologies': 9,
#          'Nascentpath': 1,
#          'Andeo Group LLC': 2,
#          'United Construction & Restoration': 1,
#          'Rapport IT Services': 4,
#          'EGlobalTech': 16,
#          'LaMotte Company': 1,
#          'Greenspring Associates': 7,
#          'EMMES': 12,
#          'KaiHonua': 7,
#          'Cayuse Holdings': 30,
#          'Parsons': 88,
#          'CollabraLink Technologies': 9,
#          'Breakthru Beverage Group': 18,
#          'eGlobalTech': 1,
#          'Phyton Advisors': 24,
#          'University of Maryland Medical System': 80,
#          'r2i Holdings Inc': 2,
#          'Emergent Biosolutions': 61,
#          'Intelliverse Solutions Group': 4,
#          'Tista Science and Technology Corporation': 23,
#          'Sekon': 85,
#          'Lupin Pharmaceuticals Inc.': 1,
#          'Booz Allen Hamilton': 1258,
#          'B3 Group Inc': 11,
#          'Brown Advisory': 6,
#          'IMPAQ International': 11,
#          'Spalding Consulting, Inc.': 22,
#          'Analytica': 49,
#          'Accenture': 1464,
#          'CareFirst BlueCross BlueShield': 65,
#          'T. Rowe Price': 38,
#          'Common Securitization Solutions': 11,
#          'InTec, LLC': 5,
#          'Aurotech, Inc.': 8,
#          'PAE': 26,
#          'Lenmar Consulting': 8,
#          'Element Fleet Management': 5,
#          'Johns Hopkins Health System': 12,
#          'Zachary Piper Solutions': 39,
#          'IQuasar': 14,
#          'Signature Consulting Group, LLC': 2,
#          'MedStar Medical Group LLC': 1,
#          'Frederick National Laboratory': 22,
#          'Computing Concepts Inc': 17,
#          'City of Baltimore, MD': 6,
#          'BurnAlong': 1,
#          'Precise Software Solutions, Inc.': 15,
#          'NSF International': 5,
#          'UM Rehabilitation & Orthopaedic Institute': 9,
#          'Catalent Pharma Solutions': 33,
#          'UMass Memorial': 2,
#          'The Hanover Insurance Group': 75,
#          'Bridge Over Troubled Waters': 19,
#          'Miracle Systems, LLC': 3,
#          'Rodenhiser Home Services': 3,
#          'Foundation Medicine, Inc.': 17,
#          'MassMutual': 65,
#          'Akamai': 21,
#          "Boston Children's Hospital": 24,
#          'Cambridge Savings Bank': 5,
#          'LifeShare Blood Centers': 9,
#          'Hash Technologies': 27,
#          "LIPSEY'S": 1,
#          'Blue Cross Blue Shield of Louisiana': 18,
#          'Humana': 176,
#          '4 Arrows': 1,
#          'Kansas Department of Aging and Disability Services': 1,
#          'University of Kansas': 5,
#          'KCAS Bioanalytical & Biomarker Services': 9,
#          'MGP': 4,
#          'Computershare': 13,
#          'OTSI USA': 2,
#          'Henry Industries, Inc': 2,
#          'Epiq Systems, Inc.': 25,
#          'MilliporeSigma': 11,
#          'EO Foundation': 1,
#          'Way Finders': 2,
#          'Wayfair': 203,
#          'Carillon Assisted Living': 9,
#          'Wells Fargo Bank': 290,
#          'SYSTEMTEC': 14,
#          'State Employees Credit Union': 12,
#          'UnityBPO': 4,
#          'LEO Pharma Inc.': 10,
#          'Rev Hugh Cooper Admin Center': 17,
#          'LINDT & SPRUNGLI': 1,
#          'Fortira Inc': 15,
#          'Hackensack Meridian Health': 9,
#          'Talan': 2,
#          'Bristol-Myers Squibb': 77,
#          'Bloomberg': 125,
#          'Conduent': 111,
#          'SpectraMedix': 9,
#          'UBS': 95,
#          "Schraft's 2.0 Pharmacy": 1,
#          'Pharma RI International': 22,
#          'Kutir Technologies': 1,
#          'Bottomline Technologies': 5,
#          'Connection, Inc.': 5,
#          'Marsh Consulting Services': 1,
#          'Combined Computer Resources': 1,
#          'FIT Staffing': 4,
#          'Green House Data': 19,
#          'Planet Fitness World Headquarters': 4,
#          'Behavior Matters LLC': 3,
#          'Liberty Mutual Insurance': 227,
#          'NRC Health': 10,
#          'Lincoln Financial': 71,
#          'Tequent Technologies': 2,
#          'IT Automation LLC': 1,
#          'Brighthouse Financial': 55,
#          'Agdata': 5,
#          'Pure Precision LLC': 1,
#          "Lowe's Inc.": 36,
#          'Red Hat Software': 80,
#          'GPM, Corp.': 4,
#          'Golden Tech Systems': 24,
#          'Golden Tech Systems Inc.': 29,
#          'SPX': 4,
#          'V-Tech Solutions': 29,
#          'Fisec Global': 2,
#          'ConvaTec': 4,
#          'London Stock Exchange Group': 8,
#          'AveXis': 6,
#          'Tekwissen': 4,
#          'Truist': 3,
#          'TekWissen Group': 10,
#          'Savantis Solutions LLC': 5,
#          'XPO Logistics': 113,
#          'Prutech Solutions': 9,
#          'Inmar': 7,
#          'Infovisa, Inc.': 3,
#          'Kontoor Brands': 7,
#          'Truist Financial': 164,
#          'UNC-Chapel Hill': 51,
#          'Ardor IT Solutions': 3,
#          'Coastal Horizons Center, Inc.': 2,
#          'Kaushal delivery services': 3,
#          'Tahill, Inc': 1,
#          'TransPro Consulting': 5,
#          'Case Farms, LLC': 1,
#          'Jacobs': 172,
#          'Retail Business Services': 19,
#          'Quantico Tactical': 1,
#          'Marine Corps Civilian Careers': 9,
#          'Access Family Services': 8,
#          'State of North Carolina': 62,
#          'Resource InfoSoft, Inc.': 1,
#          'Next Generation Technology': 14,
#          'GSK': 147,
#          'NetApp': 23,
#          'radgov': 3,
#          'Ark Solutions': 5,
#          'software people incorporation': 1,
#          'Allstate': 81,
#          'Unicorn Technologies, LLC': 7,
#          'System Soft Technologies': 13,
#          'ECR Software Corporation': 3,
#          'Cubic Corporation': 21,
#          'GreyMatterTech, Corp.': 3,
#          'Eisai': 15,
#          'The Brunswick Group': 1,
#          'Digi555': 16,
#          'Horizon Blue Cross Blue Shield of New Jersey': 39,
#          'Prana Gourmet Foods': 1,
#          'Integrated Technology Strategies, Inc.': 13,
#          'Meridian Technologies, Inc.': 6,
#          'Mercer County Community College': 4,
#          'UNITED PARCEL SERVICE': 36,
#          'Markov Processes International (MPI)': 1,
#          'RCN': 1,
#          'Broadridge': 131,
#          'Akvarr Inc': 1,
#          'Ace-stack LLC': 5,
#          'Wakefern Food Corp.': 2,
#          'GetResource Inc.': 2,
#          'TD Bank': 42,
#          'Securitas USA - Corporate Services': 1,
#          'ASRC Federal Holding Company': 62,
#          'BECHT': 6,
#          'Mars': 33,
#          'Securitas': 2,
#          'Pfizer': 73,
#          'Rutgers University': 38,
#          'Prudential': 39,
#          'ConnectiveRx': 20,
#          'Woongjin, Inc': 68,
#          'KVRA Tech Inc': 15,
#          'Pinnacle Treatment Centers': 3,
#          'Daiichi Sankyo, Inc.': 15,
#          'Peapod Digital Labs': 32,
#          'Synapse SEM': 2,
#          'Marathon Physical Therapy': 1,
#          'MASx': 2,
#          'NN, Inc.': 1,
#          'Aptima': 7,
#          "BJ's Wholesale Club, Inc.": 39,
#          'Briljent': 13,
#          'Definitive Healthcare': 25,
#          'Hawkins Point Partners': 8,
#          'Cardinal Health': 90,
#          'Vantage Deluxe World Travel': 4,
#          'John Hancock': 17,
#          'Tufts University': 1,
#          'Southcoast Health System': 7,
#          'HMS': 10,
#          'Dept of Environmental Protect': 2,
#          'Medicem, Inc.': 2,
#          'Rangam Consultants Inc.': 7,
#          'PRIMUS Global Services, Inc': 6,
#          'BNY Mellon': 248,
#          'Indigo': 26,
#          'S&P Global': 86,
#          'IT Excel': 7,
#          'MOBE, LLC': 4,
#          'Michael Page': 15,
#          'Visiting Nurse Service of New York': 32,
#          'eNGINE': 51,
#          'Brookfield Properties': 6,
#          'Titan Professional Resources': 4,
#          'PPT Consulting': 3,
#          'Criterion Executive Search': 4,
#          'Aston Carter': 20,
#          'CTG': 9,
#          'Aerotek': 64,
#          'QuTech': 2,
#          'Vanderbilt Health': 10,
#          'Hager Environmental and Atmospheric Technologies (HEAT)': 5,
#          'Bull Run Group': 1,
#          'Capital Staffing Solutions': 23,
#          'ProLink Staffing': 9,
#          '21st Century Staffing': 1,
#          'Internal Data Resources': 36,
#          'ServiceSource': 8,
#          'Ascension': 74,
#          'Fortera Federal Credit Union': 2,
#          'Monogram Food Solutions': 1,
#          'State of Tennessee': 83,
#          'BlueCross BlueShield of Tennessee': 15,
#          'Clayton Homes': 45,
#          'Delek US': 7,
#          "Sportsman's Warehouse": 2,
#          'First PREMIER Bank and PREMIER Bankcard': 3,
#          'Rosenbauer South Dakota, LLC': 1,
#          'South Dakota State Government': 12,
#          'Icloudnow': 2,
#          'Regional Finance': 7,
#          'Okaya Corp': 28,
#          'Canal Insurance Company': 6,
#          'State of South Carolina': 87,
#          'Honeywell': 177,
#          'Neighborhood Health Plan of RI': 6,
#          'TotalMed, Inc.': 4,
#          'Abarca Health, LLC': 6,
#          'Metro IT Resources, Inc.': 1,
#          'IDEAnovations LLC': 1,
#          'Asociación de Salud Primaria de Puerto Rico (ASPPR)': 1,
#          'FM Global': 27,
#          'Merck': 154,
#          'Banco Popular de Puerto Rico': 14,
#          'Coventry': 4,
#          'SoftAppDesigns': 3,
#          'Cigars International': 7,
#          'Piper Companies': 252,
#          'Herspiegel Consulting': 3,
#          'WellSpan Health': 16,
#          'C-Pearl LLC': 1,
#          'Angeion Group': 6,
#          'The Hershey Company': 13,
#          "Children's Hospital of Philadelphia": 129,
#          'Erie Insurance': 28,
#          'Integress Inc.': 22,
#          'Sapiens': 28,
#          'AllianceRx Walgreens Prime': 16,
#          'biBERK Business Insurance': 1,
#          'Community College of Allegheny County': 4,
#          'Lenmar Consulting Inc.': 3,
#          'TE Connectivity': 27,
#          'Elite Sportswear L.P. (GK Elite)': 1,
#          'Infospeeds services': 1,
#          'Visionet Systems Inc': 1,
#          'Systems Ltd': 10,
#          'Gateway Health Plan': 3,
#          'DSC Logistics': 4,
#          'Glatfelter Insurance Group': 7,
#          'Highmark Inc': 35,
#          'Providence Health & Services (Main)': 1,
#          'Elyon International': 3,
#          'Moda Health': 48,
#          'G L Suite Inc': 4,
#          'Northwest Community Credit Union': 3,
#          'AVANGRID RENEWABLES, LLC': 1,
#          'University of Western States': 1,
#          'CareOregon': 7,
#          'Forfeiture Support Associates': 115,
#          'Noah Consulting': 2,
#          'Tailwind': 15,
#          'GlobalHealth': 3,
#          'Oregon Health & Science University': 24,
#          'Inspire Brands': 15,
#          'MidFirst Bank': 21,
#          'Oklahoma Turnpike Authority': 4,
#          'National Cooperative Bank': 9,
#          "Nationwide Children's Hospital": 21,
#          'Applied Medical Technology, Inc.': 4,
#          "Ohio's Electric Cooperatives": 6,
#          'Vaco': 167,
#          'Fifth Third Bank': 71,
#          'Progressive': 118,
#          'Rumpke': 1,
#          'Vertical Knowledge': 2,
#          'Greif': 1,
#          'Ripple Junction Design Company': 4,
#          'Greater Cleveland Food Bank': 3,
#          'Compugra Systems Inc': 4,
#          'Futurety': 4,
#          'Marathon Petroleum Corporation': 10,
#          'Alkermes, Inc.': 4,
#          'Reynolds and Reynolds': 24,
#          'Total Quality Logistics (TQL)': 12,
#          'PatientPoint': 8,
#          'Fleet Team': 1,
#          'Trimble': 39,
#          'University of Dayton': 14,
#          'Covetrus': 3,
#          'Van Wert Health': 2,
#          'New York Technology Partners': 4,
#          'Northwell health': 22,
#          'Piping Rock Health Products': 10,
#          'Andre Global': 1,
#          'Layer 7 Data Solutions': 55,
#          'Montefiore Medical Center': 17,
#          'KPH Healthcare Services': 3,
#          'Global Channel Management,Inc': 2,
#          'Crestwood Technology Group Corp': 2,
#          'Synechron': 27,
#          'Saisystems International': 7,
#          'Genpact': 42,
#          'Tops Markets LLC': 1,
#          "Women's World Banking": 1,
#          'Northwell Health': 77,
#          'Nuvance Health': 2,
#          'Medical Answering Services, LLC': 2,
#          'Krishna Gems': 2,
#          'SAIS SERVICE': 5,
#          'Teladoc Health': 37,
#          'VTS': 9,
#          'Cquest': 7,
#          'VB TECH INC': 2,
#          'Havas': 16,
#          'Payability': 9,
#          'NetCloudTek': 3,
#          'Barrett Industries (110)': 15,
#          'Museum of Ice Cream': 1,
#          'eiWorkflow Solutions, LLC': 117,
#          'Brooklinen': 2,
#          'Newspaper Administration': 1,
#          'Crossix Solutions': 4,
#          'Keyrus': 1,
#          'First Derivatives': 5,
#          'New York City NYC HOUSING AUTHORITY': 2,
#          'Morgan Stanley': 63,
#          'Luminous Analytics': 7,
#          'Cloud and Things Inc': 83,
#          'Blackstone Group': 20,
#          'Ann Enterprises, Inc. (dba AnnSolutions.com)': 14,
#          ...})
